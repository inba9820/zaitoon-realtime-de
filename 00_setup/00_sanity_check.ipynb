# %%
spark.sql("SELECT current_catalog(), current_schema()").show()
spark.sql("SHOW SCHEMAS IN zaitoon_catalog").show()

# %%
display(dbutils.fs.ls("/Volumes/zaitoon_catalog/bronze/raw_events"))

# %%
spark.table("zaitoon_catalog.silver.lead_snapshots").select("snapshot_taken_at").distinct().orderBy("snapshot_taken_at").show(truncate=False)
# Out:
# +--------------------------+
# |snapshot_taken_at         |
# +--------------------------+
# |2026-09-19 08:45:06.795875|
# |2026-09-21 05:23:42.055271|
# +--------------------------+
